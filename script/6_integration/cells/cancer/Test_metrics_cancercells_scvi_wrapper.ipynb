# %% [markdown]
# # Testing scib metrics on cancer cells integration with scvi implementation of scib

# %%
import scanpy as sc
import pandas as pd
import scvi
from scib_metrics.benchmark import Benchmarker
# Out:
# Global seed set to 0

# %% [markdown]
# I did the first part of this notebook on a separate python file (Test_metrics_cancercells_scvi_wrapper.py) due to memory issues and saved the file with the complete embeddings.
#
# So now you can read the file '/group/testa/Project/OvarianAtlas/Integrated_data/atlas_cancer_batch_corr_metrics.h5ad' to plot the metrics.

# %%
adata = sc.read('/group/testa/Project/OvarianAtlas/Integrated_data/atlas_cancer_batch_corr_metrics.h5ad')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 adata = sc.read('/group/testa/Project/OvarianAtlas/Integrated_data/atlas_cancer_batch_corr_metrics.h5ad')
#
# File ~/miniconda3/envs/scvi/lib/python3.9/site-packages/scanpy/readwrite.py:112, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     110 filename = Path(filename)  # allow passing strings
#     111 if is_valid_filename(filename):
# --> 112     return _read(
#     113         filename,
#     114         backed=backed,
#     115         sheet=sheet,
#     116         ext=ext,
#     117         delimiter=delimiter,
#     118         first_column_names=first_column_names,
#     119         backup_url=backup_url,
#     120         cache=cache,
#     121         cache_compression=cache_compression,
#     122         **kwargs,
# ...

# %%
bm = Benchmarker(
    adata_HDG,
    batch_key="paper_ID",
    label_key="tissue-treatment",
    embedding_obsm_keys=['X_2500_scANVI', 'X_2500_scVI', 'X_umap_2500_scANVI', 'X_pca_2500_scANVI', 'X_pca_scANVI_HDG', 'X_umap_scANVI_HDG', 'X_HDG_scANVI', 
                         'X_HDG_scVI', 'X_umap_HDG_scANVI', 'X_pca_HDG_scANVI', 'X_umap_scgen_HDG', 'X_pca_scgen_HDG'],
    n_jobs=-1,
)
bm.benchmark()
# Out:
# ...
# Embeddings:   0%|          | 0/14 [00:00<?, ?it/s]WARNING:jax._src.lib.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# INFO     Ascites_NACT consists of a single batch or is too small. Skip.
# INFO     Primary_CHT consists of a single batch or is too small. Skip.
# INFO     Primary_NACT consists of a single batch or is too small. Skip.
# Embeddings:   7%|▋         | 1/14 [00:23<05:07, 23.66s/it]
# INFO     Ascites_NACT consists of a single batch or is too small. Skip.
# INFO     Primary_CHT consists of a single batch or is too small. Skip.
# INFO     Primary_NACT consists of a single batch or is too small. Skip.
# Embeddings:  14%|█▍        | 2/14 [00:30<02:43, 13.64s/it]
# INFO     Ascites_NACT consists of a single batch or is too small. Skip.
# INFO     Primary_CHT consists of a single batch or is too small. Skip.
# INFO     Primary_NACT consists of a single batch or is too small. Skip.
# ...

# %%
bm.plot_results_table(min_max_scale=False)

# %%
bm.plot_results_table(min_max_scale=True)

# %%
df = bm.get_results(min_max_scale=False)
print(df)
# Out:
#                      Isolated labels        KMeans NMI        KMeans ARI  \
# Embedding
# X_2500_scANVI               0.484962          0.062596          0.025106
# X_2500_scVI                  0.47226          0.049064          0.019605
# X_umap_2500_scANVI          0.502346          0.039976          0.007191
# X_pca_2500_scANVI           0.555727          0.027691          0.005231
# X_pca_scANVI_HDG            0.667536          0.073353          0.026367
# X_umap_scANVI_HDG           0.530604          0.070534          0.018906
# X_HDG_scANVI                0.446133           0.03924          0.016294
# X_HDG_scVI                  0.444354          0.038282          0.021911
# X_umap_HDG_scANVI           0.506522          0.095662          0.028422
# X_pca_HDG_scANVI            0.667536          0.073353          0.026367
# X_umap_scgen_HDG            0.520616          0.546708          0.368867
# X_pca_scgen_HDG             0.604071          0.373882          0.260692
# ...
