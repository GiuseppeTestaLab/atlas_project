# %%
# Plotting atlas cells annotated

## Import libraries
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import configparser

# Read configuration file
config = configparser.ConfigParser()
config.read('../../utils/config.ini')

utilsPath = config.get('DEFAULT', 'utilsPath')
rawPath = config.get('DEFAULT', 'rawPath')
figPath = config.get('DEFAULT', 'figPath')

## Initialize directories
initDir = rawPath + 'atlas_annotated/'

## Set figures parameters
sc.settings.set_figure_params(dpi_save=300, frameon=False, format='png')
sc.settings.set_figure_params(transparent=True)
sc.settings.figdir = figPath + "atlas_annotated/"

# %%
palette_tissue = {'Metastasis':'#C20078', 'Ascites':'#00008B', 'Primary':'#FAC205'}
palette_max = {'HematopoieticMSK':'#9addfb', 'CancerMSK':'#F4BBC9', 'FibroblastsMSK':'#B3E6B5', 'EndothelialMSK':'#FC5A50'}

# %%
## Load the data
adata = sc.read_h5ad(initDir + 'atlas_embeddings_cell_labelled_with_ontologies.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1487842 × 17063
#     obs: 'tissue', 'developmental_stage', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'CancerMSK', 'EndothelialMSK', 'FibroblastsMSK', 'HematopoieticMSK', 'max', 'cell_types', 'ontologies_from_seacells', 'major_celltypes'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'max_colors', 'neighbors', 'ontologies_from_seacells_colors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'

# %%
## Plot UMAPs
sc.pl.umap(adata, color=['max'], palette = palette_max, frameon=False, save='_main_celltypes.png')
sc.pl.umap(adata, color=['ontologies_from_seacells'], frameon=False, save='_ontologies_from_seacells.png')
sc.pl.umap(adata, color=['tissue'], palette = palette_tissue, frameon=False, save='_tissue.png')
sc.pl.umap(adata, color=['treatment'], frameon=False, save='_treatment.png')
sc.pl.umap(adata, color=['anatomical_location'], frameon=False, save='_anatomical_location.png')
sc.pl.umap(adata, color=['paper_ID'], frameon=False, save='_patients.png')
sc.pl.umap(adata, color=['dataset'], frameon=False, save='_dataset.png')
# Out:
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_main_celltypes.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_ontologies_from_seacells.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_tissue.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_treatment.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_anatomical_location.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_patients.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file /group/testa/Project/OvarianAtlas/atlas_project/plots_def/atlas_annotated/umap_dataset.png
# /home/marta.sallese/ov_cancer_atlas/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
