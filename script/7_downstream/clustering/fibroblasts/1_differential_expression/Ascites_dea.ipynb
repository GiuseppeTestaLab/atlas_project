# %% [markdown]
# # Differential expression and gene ontolgies of fibroblasts integrated SEACells: Ascites

# %%
import os
import logging
import shutil

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib import colors
from matplotlib import rcParams

# %%
from gprofiler import GProfiler

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.9.2
# scanpy      1.9.2
# -----
# PIL                 10.0.0
# anyio               NA
# asttokens           NA
# attr                23.1.0
# babel               2.12.1
# backcall            0.2.0
# brotli              1.0.9
# certifi             2023.07.22
# cffi                1.15.0
# charset_normalizer  3.2.0
# comm                0.1.4
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           5.1.1
# defusedxml          0.7.1
# exceptiongroup      1.1.3
# executing           1.2.0
# fastjsonschema      NA
# gprofiler           1.0.0
# h5py                3.9.0
# idna                3.4
# igraph              0.10.6
# importlib_resources NA
# ipykernel           6.25.0
# ipywidgets          8.1.0
# jedi                0.19.0
# jinja2              3.1.2
# joblib              1.3.2
# json5               NA
# jsonschema          4.17.3
# jupyter_events      0.6.3
# jupyter_server      2.7.3
# jupyterlab_server   2.24.0
# kiwisolver          1.4.5
# leidenalg           0.10.1
# llvmlite            0.40.1
# markupsafe          2.1.1
# matplotlib          3.7.2
# mpl_toolkits        NA
# natsort             8.4.0
# nbformat            5.9.2
# numba               0.57.1
# numpy               1.22.3
# overrides           NA
# packaging           23.1
# pandas              1.4.2
# parso               0.8.3
# patsy               0.5.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.10.0
# plotly              5.17.0
# prometheus_client   NA
# prompt_toolkit      3.0.39
# psutil              5.9.0
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pvectorc            NA
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.16.1
# pyparsing           3.0.9
# pyrsistent          NA
# pythonjsonlogger    NA
# pytz                2023.3.post1
# requests            2.31.0
# rfc3339_validator   0.1.4
# rfc3986_validator   0.1.1
# scipy               1.11.2
# seaborn             0.12.2
# send2trash          NA
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.3.0
# sniffio             1.3.0
# socks               1.7.1
# stack_data          0.6.2
# statsmodels         0.14.0
# texttable           1.6.7
# threadpoolctl       3.2.0
# tornado             6.3.2
# traitlets           5.9.0
# typing_extensions   NA
# urllib3             2.0.4
# wcwidth             0.2.6
# websocket           1.6.2
# yaml                6.0
# zipp                NA
# zmq                 25.1.0
# -----
# IPython             8.15.0
# jupyter_client      8.3.1
# jupyter_core        5.3.1
# jupyterlab          4.0.5
# -----
# Python 3.9.17 (main, Jul  5 2023, 20:41:20) [GCC 11.2.0]
# Linux-4.18.0-372.32.1.el8_6.x86_64-x86_64-with-glibc2.31
# -----
# Session information updated at 2023-12-05 13:42

# %%
pwd
# Out:
# '/home/marta.sallese/ov_cancer_atlas/atlas_project/script/downstream/clustering/fibroblasts'

# %%
import sys
sys.path.insert(1, '/home/marta.sallese/ov_cancer_atlas/atlas_project/script/downstream/clustering/cancer')

# %%
from plotting_bubble import scale_data_5_75, plot_enrich

# %%
adata = sc.read('/group/testa/Project/OvarianAtlas/Integrated_data_hdg_new/seacells_fibroblasts_hdg_patients_batch_corr_scgen_tissuetreat.h5ad')
# adata = sc.read('/group/testa/Project/OvarianAtlas/atlas_project/raw_data/integration/metacells/seacells_fibroblasts_hdg_patients_batch_corr_scgen_tissuetreat.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6696 × 17054
#     obs: 'tissue', 'developmental_stage', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset', 'SEACell', '# Single Cells', 'tissue-treatment', '_scvi_batch', '_scvi_labels'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'
#     obsm: 'corrected_latent', 'latent'

# %%
adata.obs = adata.obs.drop(columns=['_scvi_batch', '_scvi_labels'])

# %%
hvg = pd.read_csv('/home/marta.sallese/ov_cancer_atlas/Atlas_scripts/HDG_new/Tables/atlas_hdg_common_dispersion_patients_fibroblasts.csv',  index_col=0)
# hvg = pd.read_csv('/home/marta.sallese/ov_cancer_atlas/atlas_project/script/hdg/cancer/atlas_fibroblasts_hdg_dispersion_patients.csv',  index_col=0)

# %%
hvg[hvg.highly_variable]
# Out:
#            highly_variable
# LINC00115             True
# SAMD11                True
# NOC2L                 True
# PLEKHN1               True
# HES4                  True
# ...                    ...
# C21orf58              True
# S100B                 True
# MT-ND2                True
# MT-CO3                True
# MT-CYB                True
#
# [5097 rows x 1 columns]

# %%
hvg.highly_variable.sum()
# Out:
# 5097

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [FAM87B, LINC00115, FAM41C, SAMD11, NOC2L, KLHL17, PLEKHN1, HES4, ISG15, AGRN, RNF223, C1orf159, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, UBE2J2, SCNN1D, ACAP3, PUSL1, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20, ANKRD65, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, MIB2, MMP23B, CDK11B, SLC35E2B, CDK11A, NADK, GNB1, CALML6, TMEM52, GABRD, PRKCZ, SKI, MORN1, RER1, PEX10, PLCH2, PANK4, HES5, TNFRSF14, MMEL1, TTC34, PRDM16, ARHGEF16, MEGF6, TPRG1L, WRAP73, TP73, CCDC27, SMIM1, LRRC47, CEP104, DFFB, C1orf174, LINC01134, AJAP1, NPHP4, KCNAB2, CHD5, RPL22, RNF207, ICMT, LINC00337, GPR153, ACOT7, HES2, ESPN, TNFRSF25, PLEKHG5, NOL9, TAS1R1, ZBTB48, KLHL21, PHF13, THAP3, DNAJC11, CAMTA1, VAMP3, PER3, UTS2, TNFRSF9, PARK7, ERRFI1, SLC45A1, RERE, ENO1, CA6, ...]
#
# [17054 rows x 0 columns]

# %%
adata.var['highly_variable']=hvg.highly_variable

# %%
adata.var
# Out:
#           highly_variable
# FAM87B              False
# LINC00115            True
# FAM41C              False
# SAMD11               True
# NOC2L                True
# ...                   ...
# MT-ND4L             False
# MT-ND4              False
# MT-ND5              False
# MT-ND6              False
# MT-CYB               True
#
# [17054 rows x 1 columns]

# %%
adata.var.highly_variable = adata.var.highly_variable.fillna(False)

# %%
adata.var
# Out:
#            highly_variable
# FAM87B               False
# LINC00115             True
# FAM41C               False
# SAMD11                True
# NOC2L                 True
# ...                    ...
# MT-ND4L              False
# MT-ND4               False
# MT-ND5               False
# MT-ND6               False
# MT-CYB                True
#
# [17054 rows x 1 columns]

# %%
# you can skip this passage if you specify use_highly_variable = True when computing embeddings
# adata.raw = adata
# adata = adata[:, adata.var.highly_variable]

# %%
adata.var_names
# Out:
# Index(['FAM87B', 'LINC00115', 'FAM41C', 'SAMD11', 'NOC2L', 'KLHL17', 'PLEKHN1',
#        'HES4', 'ISG15', 'AGRN',
#        ...
#        'MT-CO2', 'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L', 'MT-ND4',
#        'MT-ND5', 'MT-ND6', 'MT-CYB'],
#       dtype='object', length=17054)

# %%
cell_cycle_genes = [x.strip() for x in open('/home/marta.sallese/ov_cancer_atlas/regev_lab_cell_cycle_genes.txt')]

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]

sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# WARNING: genes are not in var_names and ignored: ['UHRF1', 'MLF1IP', 'CASP8AP2']
# WARNING: genes are not in var_names and ignored: ['FAM64A', 'HN1']
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):

# %%
adata.obs
# Out:
#                                            tissue developmental_stage  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    Metastasis      Advanced stage
# SEACell-134_Geistlinger_59_Metastasis  Metastasis      Advanced stage
# SEACell-104_Geistlinger_59_Metastasis  Metastasis      Advanced stage
# SEACell-94_Geistlinger_59_Metastasis   Metastasis      Advanced stage
# SEACell-15_Geistlinger_59_Metastasis   Metastasis      Advanced stage
# ...                                           ...                 ...
# SEACell-19_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-47_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-14_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-39_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-2_Vasquez_118_Metastasis       Metastasis      Advanced stage
#
#                                       treatment  recurrence tumor_stage  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis         CHT  Recurrence          IV
# SEACell-134_Geistlinger_59_Metastasis       CHT  Recurrence          IV
# SEACell-104_Geistlinger_59_Metastasis       CHT  Recurrence          IV
# SEACell-94_Geistlinger_59_Metastasis        CHT  Recurrence          IV
# SEACell-15_Geistlinger_59_Metastasis        CHT  Recurrence          IV
# ...                                         ...         ...         ...
# SEACell-19_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-47_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-14_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-39_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-2_Vasquez_118_Metastasis          Naive     Unknown         IVB
#
#                                              paper_ID anatomical_location  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    Geistlinger_59             Omentum
# SEACell-134_Geistlinger_59_Metastasis  Geistlinger_59             Omentum
# SEACell-104_Geistlinger_59_Metastasis  Geistlinger_59             Omentum
# SEACell-94_Geistlinger_59_Metastasis   Geistlinger_59             Omentum
# SEACell-15_Geistlinger_59_Metastasis   Geistlinger_59             Omentum
# ...                                               ...                 ...
# SEACell-19_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-47_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-14_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-39_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-2_Vasquez_118_Metastasis          Vasquez_118          Peritoneum
#
#                                            dataset      SEACell  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    Geistlinger    SEACell-9
# SEACell-134_Geistlinger_59_Metastasis  Geistlinger  SEACell-134
# SEACell-104_Geistlinger_59_Metastasis  Geistlinger  SEACell-104
# SEACell-94_Geistlinger_59_Metastasis   Geistlinger   SEACell-94
# SEACell-15_Geistlinger_59_Metastasis   Geistlinger   SEACell-15
# ...                                            ...          ...
# SEACell-19_Vasquez_118_Metastasis          Vasquez   SEACell-19
# SEACell-47_Vasquez_118_Metastasis          Vasquez   SEACell-47
# SEACell-14_Vasquez_118_Metastasis          Vasquez   SEACell-14
# SEACell-39_Vasquez_118_Metastasis          Vasquez   SEACell-39
# SEACell-2_Vasquez_118_Metastasis           Vasquez    SEACell-2
#
#                                        # Single Cells  tissue-treatment  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis                46    Metastasis_CHT
# SEACell-134_Geistlinger_59_Metastasis              46    Metastasis_CHT
# SEACell-104_Geistlinger_59_Metastasis             101    Metastasis_CHT
# SEACell-94_Geistlinger_59_Metastasis              129    Metastasis_CHT
# SEACell-15_Geistlinger_59_Metastasis               95    Metastasis_CHT
# ...                                               ...               ...
# SEACell-19_Vasquez_118_Metastasis                  13  Metastasis_Naive
# SEACell-47_Vasquez_118_Metastasis                  22  Metastasis_Naive
# SEACell-14_Vasquez_118_Metastasis                  42  Metastasis_Naive
# SEACell-39_Vasquez_118_Metastasis                  23  Metastasis_Naive
# SEACell-2_Vasquez_118_Metastasis                    2  Metastasis_Naive
#
#                                         S_score  G2M_score phase
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis   -0.079929  -0.568825    G1
# SEACell-134_Geistlinger_59_Metastasis -0.091447  -0.527433    G1
# SEACell-104_Geistlinger_59_Metastasis -0.360087  -1.034474    G1
# SEACell-94_Geistlinger_59_Metastasis  -0.303564  -0.929084    G1
# SEACell-15_Geistlinger_59_Metastasis  -0.115633  -0.549499    G1
# ...                                         ...        ...   ...
# SEACell-19_Vasquez_118_Metastasis     -0.000319  -0.424984    G1
# SEACell-47_Vasquez_118_Metastasis     -0.105239  -0.600772    G1
# SEACell-14_Vasquez_118_Metastasis      0.016118  -0.569303     S
# SEACell-39_Vasquez_118_Metastasis     -0.049043  -0.522532    G1
# SEACell-2_Vasquez_118_Metastasis      -0.011478  -0.287448    G1
#
# [6696 rows x 14 columns]

# %%
# inflammatory CAFs (iCAF)
sc.tl.score_genes(adata, ['IL6', 'CXCL12', 'VTN', 'CADM3', 'PLIN2', 'SERPINB2', 'KRT19', 'DES', 'CALB2', 'WT1', 'KRT7'], 
score_name = "iCAF", use_raw=False)

# matrix CAFs (mCAF)
sc.tl.score_genes(adata, ['ACTA2', 'COL11A1', 'MFAP5', 'SFRP2', 'ISLR', 'COL10A1', 'VIM', 'COL3A', 
                       'MMP11', 'PTHLH', 'FGF1', 'WNT7B', 'WNT2', 'TGFB3', 'THRC1', 'POSTN', 'VCAN', 'ZEB1'], 
score_name = "mCAF", use_raw=False)

# vascular cancer-associated fibroblasts CAFs (vCAF)
sc.tl.score_genes(adata, ['COX4I2', 'HIGD1B', 'PTP4A3', 'MCAM', 'PPP1R14A'], 
score_name = "vCAF", use_raw=False)

# STAR gene expressing CAFs (starCAF)
sc.tl.score_genes(adata, ['STAR', 'IGFBP5', 'TSPAN8', 'C7', 'ALDH1A1', 'LGR5'], 
score_name = "starCAF", use_raw=False)

#%%
adata.obs['cell_types'] = adata.obs[['iCAF', 'mCAF','vCAF', 'starCAF']].idxmax(axis=1)
adata.obs
# Out:
# WARNING: genes are not in var_names and ignored: ['COL3A', 'THRC1']
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
# WARNING: genes are not in var_names and ignored: ['MCAM']
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
#                                            tissue developmental_stage  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    Metastasis      Advanced stage
# SEACell-134_Geistlinger_59_Metastasis  Metastasis      Advanced stage
# SEACell-104_Geistlinger_59_Metastasis  Metastasis      Advanced stage
# SEACell-94_Geistlinger_59_Metastasis   Metastasis      Advanced stage
# SEACell-15_Geistlinger_59_Metastasis   Metastasis      Advanced stage
# ...                                           ...                 ...
# SEACell-19_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-47_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-14_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-39_Vasquez_118_Metastasis      Metastasis      Advanced stage
# SEACell-2_Vasquez_118_Metastasis       Metastasis      Advanced stage
#
#                                       treatment  recurrence tumor_stage  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis         CHT  Recurrence          IV
# SEACell-134_Geistlinger_59_Metastasis       CHT  Recurrence          IV
# SEACell-104_Geistlinger_59_Metastasis       CHT  Recurrence          IV
# SEACell-94_Geistlinger_59_Metastasis        CHT  Recurrence          IV
# SEACell-15_Geistlinger_59_Metastasis        CHT  Recurrence          IV
# ...                                         ...         ...         ...
# SEACell-19_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-47_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-14_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-39_Vasquez_118_Metastasis         Naive     Unknown         IVB
# SEACell-2_Vasquez_118_Metastasis          Naive     Unknown         IVB
#
#                                              paper_ID anatomical_location  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    Geistlinger_59             Omentum
# SEACell-134_Geistlinger_59_Metastasis  Geistlinger_59             Omentum
# SEACell-104_Geistlinger_59_Metastasis  Geistlinger_59             Omentum
# SEACell-94_Geistlinger_59_Metastasis   Geistlinger_59             Omentum
# SEACell-15_Geistlinger_59_Metastasis   Geistlinger_59             Omentum
# ...                                               ...                 ...
# SEACell-19_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-47_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-14_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-39_Vasquez_118_Metastasis         Vasquez_118          Peritoneum
# SEACell-2_Vasquez_118_Metastasis          Vasquez_118          Peritoneum
#
#                                            dataset      SEACell  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    Geistlinger    SEACell-9
# SEACell-134_Geistlinger_59_Metastasis  Geistlinger  SEACell-134
# SEACell-104_Geistlinger_59_Metastasis  Geistlinger  SEACell-104
# SEACell-94_Geistlinger_59_Metastasis   Geistlinger   SEACell-94
# SEACell-15_Geistlinger_59_Metastasis   Geistlinger   SEACell-15
# ...                                            ...          ...
# SEACell-19_Vasquez_118_Metastasis          Vasquez   SEACell-19
# SEACell-47_Vasquez_118_Metastasis          Vasquez   SEACell-47
# SEACell-14_Vasquez_118_Metastasis          Vasquez   SEACell-14
# SEACell-39_Vasquez_118_Metastasis          Vasquez   SEACell-39
# SEACell-2_Vasquez_118_Metastasis           Vasquez    SEACell-2
#
#                                        # Single Cells  tissue-treatment  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis                46    Metastasis_CHT
# SEACell-134_Geistlinger_59_Metastasis              46    Metastasis_CHT
# SEACell-104_Geistlinger_59_Metastasis             101    Metastasis_CHT
# SEACell-94_Geistlinger_59_Metastasis              129    Metastasis_CHT
# SEACell-15_Geistlinger_59_Metastasis               95    Metastasis_CHT
# ...                                               ...               ...
# SEACell-19_Vasquez_118_Metastasis                  13  Metastasis_Naive
# SEACell-47_Vasquez_118_Metastasis                  22  Metastasis_Naive
# SEACell-14_Vasquez_118_Metastasis                  42  Metastasis_Naive
# SEACell-39_Vasquez_118_Metastasis                  23  Metastasis_Naive
# SEACell-2_Vasquez_118_Metastasis                    2  Metastasis_Naive
#
#                                         S_score  G2M_score phase      iCAF  \
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis   -0.079929  -0.568825    G1 -0.310200
# SEACell-134_Geistlinger_59_Metastasis -0.091447  -0.527433    G1 -0.216951
# SEACell-104_Geistlinger_59_Metastasis -0.360087  -1.034474    G1  0.328189
# SEACell-94_Geistlinger_59_Metastasis  -0.303564  -0.929084    G1  0.324485
# SEACell-15_Geistlinger_59_Metastasis  -0.115633  -0.549499    G1 -0.062011
# ...                                         ...        ...   ...       ...
# SEACell-19_Vasquez_118_Metastasis     -0.000319  -0.424984    G1 -0.698757
# SEACell-47_Vasquez_118_Metastasis     -0.105239  -0.600772    G1 -0.460108
# SEACell-14_Vasquez_118_Metastasis      0.016118  -0.569303     S  1.039795
# SEACell-39_Vasquez_118_Metastasis     -0.049043  -0.522532    G1 -0.954020
# SEACell-2_Vasquez_118_Metastasis      -0.011478  -0.287448    G1 -0.469279
#
#                                            mCAF      vCAF   starCAF cell_types
# SEACell_patient_tissue
# SEACell-9_Geistlinger_59_Metastasis    1.147510  3.343796 -0.589536       vCAF
# SEACell-134_Geistlinger_59_Metastasis  1.244232  3.335443 -0.492740       vCAF
# SEACell-104_Geistlinger_59_Metastasis  2.073222  0.972181  0.038503       mCAF
# SEACell-94_Geistlinger_59_Metastasis   2.173957  1.138880 -0.062631       mCAF
# SEACell-15_Geistlinger_59_Metastasis   0.754192  1.904560 -0.531354       vCAF
# ...                                         ...       ...       ...        ...
# SEACell-19_Vasquez_118_Metastasis      1.214978  2.859798 -0.392312       vCAF
# SEACell-47_Vasquez_118_Metastasis      1.963317  0.477240 -0.046297       mCAF
# SEACell-14_Vasquez_118_Metastasis      1.095167 -0.351659 -0.136661       mCAF
# SEACell-39_Vasquez_118_Metastasis      1.106482  3.012738 -0.511879       vCAF
# SEACell-2_Vasquez_118_Metastasis       1.216199  1.923907 -0.140255       vCAF
#
# [6696 rows x 19 columns]

# %% [markdown]
# ### Ascites

# %%
adata_as = adata[(adata.obs['tissue'] == 'Ascites')]

# %%
adata_as
# Out:
# View of AnnData object with n_obs × n_vars = 461 × 17054
#     obs: 'tissue', 'developmental_stage', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset', 'SEACell', '# Single Cells', 'tissue-treatment', 'S_score', 'G2M_score', 'phase', 'iCAF', 'mCAF', 'vCAF', 'starCAF', 'cell_types'
#     var: 'highly_variable'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'
#     obsm: 'corrected_latent', 'latent'

# %%
sc.tl.pca(adata_as, use_highly_variable = True)

# %%
sc.pp.neighbors(adata_as, n_neighbors=10, n_pcs=50)
sc.tl.umap(adata_as)
# Out:
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
sc.pl.umap(adata_as, color=["treatment"], frameon=False)
sc.pl.umap(adata_as, color=["anatomical_location"], frameon=False)
sc.pl.umap(adata_as, color=["phase"], frameon=False)
# Out:
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
leidenTotal=[]
for i in np.arange(0.01, 2.0, 0.1):
    sc.tl.leiden(adata_as,resolution = i,key_added="leiden-{}".format(round(i,2)))
    leidenTotal.append("leiden-{}".format(round(i,2)))

# %%
leidenTotal
# Out:
# ['leiden-0.01',
#  'leiden-0.11',
#  'leiden-0.21',
#  'leiden-0.31',
#  'leiden-0.41',
#  'leiden-0.51',
#  'leiden-0.61',
#  'leiden-0.71',
#  'leiden-0.81',
#  'leiden-0.91',
#  'leiden-1.01',
#  'leiden-1.11',
#  'leiden-1.21',
#  'leiden-1.31',
#  'leiden-1.41',
#  'leiden-1.51',
#  'leiden-1.61',
#  'leiden-1.71',
#  'leiden-1.81',
#  'leiden-1.91']

# %%
for i in leidenTotal:
   sc.pl.umap(adata_as, color=i, frameon=False)
# Out:
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
dedf={}
for lei in leidenTotal:
    dedf[lei]={}
    sc.tl.rank_genes_groups(adata_as, groupby=lei, method='wilcoxon', key_added = "wilcoxon_"+lei)
    for cl in adata_as.obs[lei].unique():
        dedf[lei][cl] = sc.get.rank_genes_groups_df(adata_as, group=cl, key ='wilcoxon_'+lei)
# Out:
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/preprocessing/_utils.py:11: RuntimeWarning: Mean of empty slice.
#   mean_sq = np.multiply(X, X).mean(axis=axis, dtype=np.float64)
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:324: RuntimeWarning: invalid value encountered in true_divide
#   scores[group_index, :] = (
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/marta.sallese/miniconda3/envs/gprofiler/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
directory_root = "/home/marta.sallese/ov_cancer_atlas/atlas_project/script/downstream/clustering/fibroblasts/ascites/"

errorDic={}
log_file = directory_root + 'ascites.log'

# Check if the log exists
if os.path.isfile(log_file):
# If it doesn't exist, create it
    os.remove(log_file)

logging.basicConfig(filename=log_file, level=logging.INFO) 
                    # format='%(ascites)s %(levelname)s %(name)s %(message)s')
logger=logging.getLogger(__name__)

for lei in leidenTotal:
    errorDic[lei]={}
    directory = directory_root + lei
    # Check if the directory exists
    if not os.path.exists(directory):
        # If it doesn't exist, create it
        os.makedirs(directory)
    else:
        shutil.rmtree(directory)
        os.makedirs(directory)
    for cl in adata_as.obs[lei].unique():
        dedf[lei][cl] = sc.get.rank_genes_groups_df(adata_as, group=cl, key ='wilcoxon_'+lei)
        dedf[lei][cl].to_csv(directory + '/rank_gene_groups_df_' + cl + '.csv')
        try:
            # print(dedf[lei][cl])
            threshold1 = dedf[lei][cl].dropna(axis='rows')
            threshold2 = threshold1.loc[(threshold1['logfoldchanges'] > 1) & (threshold1['logfoldchanges'] < 100), :]
            threshold3 = threshold2.loc[threshold2['scores'] > 5, :]
            threshold4 = threshold3.loc[threshold3['pvals_adj'] < 0.05, :]
            # break
            print('{}_{}_{}_{}'.format(lei, cl, threshold4.shape[0], threshold4.scores.min()))
            # ontologia di (dedf[lei][cl])
            gp = GProfiler(return_dataframe=True)
            query = threshold4.names.to_list()
            ontology = gp.profile(organism='hsapiens', 
                                    query=query, 
                                    no_evidences=False, 
                                    background=adata_as.var_names.to_list(),
                                    sources=['GO:CC', 'GO:BP', 'GO:MF','REAC','KEGG'])
            ontology.to_csv(directory + '/gprofiler_' + cl + '.csv')
            if ontology.shape[0] > 0:
                plot_enrich(ontology, filename=directory + '/ontology_' + cl + '.png')
            else:
                logger.info('leiden {} cluster {}'.format(lei, cl))
                logger.info('ontology empty')
            
            
            errorDic[lei][cl]={}

        except Exception as e:
            errorDic[lei][cl]=e
            # with open(directory + '/ontology_' + cl + '.log', 'w') as f:
            #     f.write('error')
            logger.info('leiden {} cluster {}'.format(lei, cl))
            logger.error(e)
            continue

logging.shutdown()
# Out:
# leiden-0.01_0_0_nan
# leiden-0.11_1_13694_5.001680374145508
# leiden-0.11_0_323_5.002849578857422
# leiden-0.11_2_85_5.009979248046875
# leiden-0.11_3_109_5.064617156982422
# leiden-0.21_1_13694_5.001680374145508
# leiden-0.21_0_323_5.002849578857422
# leiden-0.21_3_117_5.0409016609191895
# leiden-0.21_2_109_5.064617156982422
# leiden-0.21_4_467_5.006621837615967
# leiden-0.31_1_13694_5.001680374145508
# leiden-0.31_0_237_5.009843349456787
# leiden-0.31_4_531_5.015397548675537
# leiden-0.31_3_117_5.0409016609191895
# leiden-0.31_2_109_5.064617156982422
# leiden-0.31_5_467_5.006621837615967
# leiden-0.41_4_13703_5.017208576202393
# leiden-0.41_0_237_5.009843349456787
# leiden-0.41_1_10989_5.0193328857421875
# leiden-0.41_5_531_5.015397548675537
# leiden-0.41_2_117_5.0409016609191895
# leiden-0.41_7_166_5.010420322418213
# leiden-0.41_6_467_5.006621837615967
# leiden-0.41_3_55_5.040968418121338
# leiden-0.51_3_13703_5.017208576202393
# leiden-0.51_0_797_5.004966735839844
# leiden-0.51_1_10989_5.0193328857421875
# leiden-0.51_5_528_5.0010457038879395
# leiden-0.51_6_72_5.014546871185303
# leiden-0.51_2_137_5.006464004516602
# leiden-0.51_4_187_5.001071929931641
# leiden-0.51_8_467_5.006621837615967
# leiden-0.51_7_7_5.053997993469238
# leiden-0.61_5_13703_5.017208576202393
# leiden-0.61_1_258_5.008877277374268
# leiden-0.61_0_10989_5.0193328857421875
# leiden-0.61_7_531_5.015397548675537
# leiden-0.61_6_72_5.014546871185303
# leiden-0.61_2_137_5.006464004516602
# leiden-0.61_9_166_5.010420322418213
# leiden-0.61_8_467_5.006621837615967
# leiden-0.61_3_55_5.040968418121338
# leiden-0.61_4_1009_5.002842426300049
# leiden-0.71_2_13703_5.017208576202393
# leiden-0.71_4_231_5.021289348602295
# leiden-0.71_0_10996_5.0281219482421875
# leiden-0.71_3_194_5.0084147453308105
# leiden-0.71_9_531_5.015397548675537
# leiden-0.71_6_72_5.014546871185303
# leiden-0.71_1_155_5.012927055358887
# leiden-0.71_11_166_5.010420322418213
# leiden-0.71_10_451_5.00123405456543
# leiden-0.71_8_7_5.053997993469238
# leiden-0.71_5_872_5.002303123474121
# leiden-0.71_7_102_5.022450923919678
# leiden-0.81_3_13703_5.017208576202393
# leiden-0.81_5_240_5.00852632522583
# leiden-0.81_1_10689_5.0018181800842285
# leiden-0.81_0_2842_5.000788688659668
# leiden-0.81_6_72_5.014546871185303
# leiden-0.81_2_137_5.006464004516602
# leiden-0.81_10_166_5.010420322418213
# leiden-0.81_9_467_5.006621837615967
# leiden-0.81_8_7_5.053997993469238
# leiden-0.81_4_1009_5.002842426300049
# leiden-0.81_7_114_5.017341136932373
# leiden-0.91_0_13724_5.00752592086792
# leiden-0.91_4_231_5.021289348602295
# leiden-0.91_5_7602_5.000214576721191
# leiden-0.91_3_9848_5.0012688636779785
# leiden-0.91_2_194_5.0084147453308105
# leiden-0.91_10_531_5.015397548675537
# leiden-0.91_7_72_5.014546871185303
# leiden-0.91_1_155_5.012927055358887
# leiden-0.91_12_166_5.010420322418213
# leiden-0.91_11_451_5.00123405456543
# leiden-0.91_9_7_5.053997993469238
# leiden-0.91_6_872_5.002303123474121
# leiden-0.91_8_102_5.022450923919678
# leiden-1.01_0_13731_5.029104709625244
# leiden-1.01_4_231_5.021289348602295
# leiden-1.01_5_7602_5.000214576721191
# leiden-1.01_2_10115_5.0004987716674805
# leiden-1.01_3_194_5.0084147453308105
# leiden-1.01_10_531_5.015397548675537
# leiden-1.01_7_72_5.014546871185303
# leiden-1.01_1_155_5.012927055358887
# leiden-1.01_12_166_5.010420322418213
# leiden-1.01_11_451_5.00123405456543
# leiden-1.01_9_7_5.053997993469238
# leiden-1.01_6_872_5.002303123474121
# leiden-1.01_8_102_5.022450923919678
# leiden-1.11_0_13703_5.017208576202393
# leiden-1.11_4_231_5.021289348602295
# leiden-1.11_6_5707_5.001286029815674
# leiden-1.11_1_10729_5.002205848693848
# leiden-1.11_8_245_5.003056526184082
# leiden-1.11_3_517_5.002511024475098
# leiden-1.11_2_112_5.00390100479126
# leiden-1.11_13_0_nan
# leiden-1.11_12_166_5.010420322418213
# leiden-1.11_10_50_5.03393030166626
# leiden-1.11_11_451_5.00123405456543
# leiden-1.11_9_7_5.053997993469238
# leiden-1.11_5_872_5.002303123474121
# leiden-1.11_7_114_5.017341136932373
# leiden-1.21_0_13703_5.017208576202393
# leiden-1.21_4_222_5.013082027435303
# leiden-1.21_3_8869_5.000027179718018
# leiden-1.21_2_10115_5.0004987716674805
# leiden-1.21_7_74_5.011375904083252
# leiden-1.21_11_531_5.015397548675537
# leiden-1.21_1_112_5.00390100479126
# leiden-1.21_13_0_nan
# leiden-1.21_12_166_5.010420322418213
# leiden-1.21_8_50_5.03393030166626
# leiden-1.21_10_451_5.00123405456543
# leiden-1.21_9_7_5.053997993469238
# leiden-1.21_5_872_5.002303123474121
# leiden-1.21_14_384_5.004157066345215
# leiden-1.21_6_114_5.017341136932373
# leiden-1.31_0_13703_5.017208576202393
# leiden-1.31_3_222_5.013082027435303
# leiden-1.31_2_8869_5.000027179718018
# leiden-1.31_1_10115_5.0004987716674805
# leiden-1.31_8_74_5.011375904083252
# leiden-1.31_11_531_5.015397548675537
# leiden-1.31_5_72_5.014546871185303
# leiden-1.31_7_98_5.010810852050781
# leiden-1.31_13_166_5.010420322418213
# leiden-1.31_9_41_5.01286506652832
# leiden-1.31_12_451_5.00123405456543
# leiden-1.31_10_7_5.053997993469238
# leiden-1.31_4_872_5.002303123474121
# leiden-1.31_14_384_5.004157066345215
# leiden-1.31_6_114_5.017341136932373
# leiden-1.41_0_13693_5.011904716491699
# leiden-1.41_2_222_5.013082027435303
# leiden-1.41_4_6139_5.001171112060547
# leiden-1.41_1_10636_5.000434875488281
# leiden-1.41_8_74_5.011375904083252
# leiden-1.41_10_531_5.015397548675537
# leiden-1.41_15_169_5.00033712387085
# leiden-1.41_13_0_nan
# leiden-1.41_6_98_5.010810852050781
# leiden-1.41_12_166_5.010420322418213
# leiden-1.41_7_41_5.01286506652832
# leiden-1.41_11_451_5.00123405456543
# leiden-1.41_9_7_5.053997993469238
# leiden-1.41_3_872_5.002303123474121
# leiden-1.41_14_384_5.004157066345215
# leiden-1.41_5_114_5.017341136932373
# leiden-1.51_1_13760_5.024981498718262
# leiden-1.51_2_222_5.013082027435303
# leiden-1.51_4_6139_5.001171112060547
# leiden-1.51_0_9751_5.001189231872559
# leiden-1.51_12_11837_5.000198841094971
# leiden-1.51_8_74_5.011375904083252
# leiden-1.51_10_531_5.015397548675537
# leiden-1.51_16_169_5.00033712387085
# leiden-1.51_14_0_nan
# leiden-1.51_6_98_5.010810852050781
# leiden-1.51_13_166_5.010420322418213
# leiden-1.51_7_41_5.01286506652832
# leiden-1.51_11_451_5.00123405456543
# leiden-1.51_9_7_5.053997993469238
# leiden-1.51_3_872_5.002303123474121
# leiden-1.51_15_384_5.004157066345215
# leiden-1.51_5_114_5.017341136932373
# leiden-1.61_5_13819_5.017559051513672
# leiden-1.61_1_222_5.013082027435303
# leiden-1.61_3_6139_5.001171112060547
# leiden-1.61_0_10551_5.000027179718018
# leiden-1.61_9_11837_5.000198841094971
# leiden-1.61_11_79_5.008354663848877
# leiden-1.61_4_454_5.008066654205322
# leiden-1.61_14_169_5.00033712387085
# leiden-1.61_13_0_nan
# leiden-1.61_6_59_5.005354404449463
# leiden-1.61_12_166_5.010420322418213
# leiden-1.61_16_139_5.041128158569336
# leiden-1.61_17_467_5.0016069412231445
# leiden-1.61_8_7_5.053997993469238
# leiden-1.61_2_872_5.002303123474121
# leiden-1.61_15_384_5.004157066345215
# leiden-1.61_7_114_5.017341136932373
# leiden-1.61_10_75_5.000198841094971
# leiden-1.71_5_13819_5.017559051513672
# leiden-1.71_1_222_5.013082027435303
# leiden-1.71_3_6139_5.001171112060547
# leiden-1.71_0_10458_5.000744342803955
# leiden-1.71_10_11837_5.000198841094971
# leiden-1.71_7_74_5.011375904083252
# leiden-1.71_9_531_5.015397548675537
# leiden-1.71_15_169_5.00033712387085
# leiden-1.71_13_0_nan
# leiden-1.71_4_59_5.005354404449463
# leiden-1.71_12_166_5.010420322418213
# leiden-1.71_17_139_5.041128158569336
# leiden-1.71_16_467_5.0016069412231445
# leiden-1.71_8_7_5.053997993469238
# leiden-1.71_2_872_5.002303123474121
# leiden-1.71_14_384_5.004157066345215
# leiden-1.71_6_114_5.017341136932373
# leiden-1.71_11_75_5.000198841094971
# leiden-1.81_11_13220_5.001794815063477
# leiden-1.81_1_222_5.013082027435303
# leiden-1.81_3_6139_5.001171112060547
# leiden-1.81_0_10636_5.000434875488281
# leiden-1.81_4_13070_5.011283874511719
# leiden-1.81_8_74_5.011375904083252
# leiden-1.81_10_531_5.015397548675537
# leiden-1.81_14_169_5.00033712387085
# leiden-1.81_13_0_nan
# leiden-1.81_6_98_5.010810852050781
# leiden-1.81_12_166_5.010420322418213
# leiden-1.81_7_41_5.01286506652832
# leiden-1.81_16_139_5.041128158569336
# leiden-1.81_17_467_5.0016069412231445
# leiden-1.81_9_7_5.053997993469238
# leiden-1.81_2_872_5.002303123474121
# leiden-1.81_15_384_5.004157066345215
# leiden-1.81_5_114_5.017341136932373
# leiden-1.91_3_13799_5.006521224975586
# leiden-1.91_0_222_5.013082027435303
# leiden-1.91_1_10926_5.011101722717285
# leiden-1.91_9_5971_5.0015130043029785
# leiden-1.91_12_11745_5.003385543823242
# leiden-1.91_6_74_5.011375904083252
# leiden-1.91_10_531_5.015397548675537
# leiden-1.91_11_162_5.000631809234619
# leiden-1.91_15_169_5.00033712387085
# leiden-1.91_14_0_nan
# leiden-1.91_5_98_5.010810852050781
# leiden-1.91_13_166_5.010420322418213
# leiden-1.91_7_41_5.01286506652832
# leiden-1.91_17_139_5.041128158569336
# leiden-1.91_18_467_5.0016069412231445
# leiden-1.91_8_7_5.053997993469238
# leiden-1.91_2_872_5.002303123474121
# leiden-1.91_16_384_5.004157066345215
# leiden-1.91_4_114_5.017341136932373

# %%
logging.shutdown()

# %%
adata_as.write_h5ad('/group/testa/Project/OvarianAtlas/atlas_project/raw_data/downstream/clustering/fibroblasts/adata_ascites_embeddings.h5ad')
