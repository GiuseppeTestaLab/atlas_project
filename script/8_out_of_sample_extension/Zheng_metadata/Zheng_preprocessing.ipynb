# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
adata = sc.read('/group/testa/Project/OvarianAtlas/Zheng2023/Adata/zheng2023_rawcounts.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 223363 × 27117
#     obs: 'sample_name', 'tissue', 'developmental_stage', 'patient_id', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata.obs
# Out:
#                                 sample_name   tissue developmental_stage  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGATGCGAC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG   HGSOC1_BC    Blood      Advanced stage
# ...                                     ...      ...                 ...
# C1_OC_cell_TGCTACCGTCCGAACC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGGGCGTTCACTATTC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTCCCAGTAACGACG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTTCCGCAGGTCTCG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TTCTCAATCACCTTAT           C1_PT  Primary      Advanced stage
#
#                                      patient_id treatment recurrence  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGATGCGAC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG              P1     Naive  Sensitive
# ...                                         ...       ...        ...
# C1_OC_cell_TGCTACCGTCCGAACC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGGGCGTTCACTATTC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTCCCAGTAACGACG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTTCCGCAGGTCTCG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TTCTCAATCACCTTAT      Carcinosarcoma     Naive  Sensitive
#
#                                 tumor_stage              paper_ID  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGATGCGAC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG        IIIC               Zheng_1
# ...                                     ...                   ...
# C1_OC_cell_TGCTACCGTCCGAACC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGGGCGTTCACTATTC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTCCCAGTAACGACG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTTCCGCAGGTCTCG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TTCTCAATCACCTTAT            IIIC  Zheng_Carcinosarcoma
#
#                                 anatomical_location dataset  n_genes  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT               Blood   Zheng     1660
# EOC1_PBMC_cell_AAACCTGAGATGCGAC               Blood   Zheng     4372
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA               Blood   Zheng     1635
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC               Blood   Zheng     1625
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG               Blood   Zheng     1269
# ...                                             ...     ...      ...
# C1_OC_cell_TGCTACCGTCCGAACC                   Ovary   Zheng     4985
# C1_OC_cell_TGGGCGTTCACTATTC                   Ovary   Zheng     5798
# C1_OC_cell_TGTCCCAGTAACGACG                   Ovary   Zheng     1583
# C1_OC_cell_TGTTCCGCAGGTCTCG                   Ovary   Zheng     2141
# C1_OC_cell_TTCTCAATCACCTTAT                   Ovary   Zheng     3496
#
#                                  n_genes_by_counts  total_counts  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT               1660        6736.0
# EOC1_PBMC_cell_AAACCTGAGATGCGAC               4372       33886.0
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA               1635        4998.0
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC               1625        6397.0
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG               1269        3766.0
# ...                                            ...           ...
# C1_OC_cell_TGCTACCGTCCGAACC                   4985       20793.0
# C1_OC_cell_TGGGCGTTCACTATTC                   5798       24396.0
# C1_OC_cell_TGTCCCAGTAACGACG                   1583        3354.0
# C1_OC_cell_TGTTCCGCAGGTCTCG                   2141        6056.0
# C1_OC_cell_TTCTCAATCACCTTAT                   3496       10310.0
#
#                                  total_counts_mt  pct_counts_mt
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT            199.0       2.954276
# EOC1_PBMC_cell_AAACCTGAGATGCGAC           1661.0       4.901729
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA            179.0       3.581433
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC            157.0       2.454275
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG            227.0       6.027616
# ...                                          ...            ...
# C1_OC_cell_TGCTACCGTCCGAACC               1401.0       6.737844
# C1_OC_cell_TGGGCGTTCACTATTC                961.0       3.939170
# C1_OC_cell_TGTCCCAGTAACGACG                133.0       3.965414
# C1_OC_cell_TGTTCCGCAGGTCTCG                540.0       8.916777
# C1_OC_cell_TTCTCAATCACCTTAT                446.0       4.325897
#
# [223363 rows x 15 columns]

# %%
adata.obs.drop(columns=['n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'], inplace=True)

# %%
adata.obs
# Out:
#                                 sample_name   tissue developmental_stage  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGATGCGAC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG   HGSOC1_BC    Blood      Advanced stage
# ...                                     ...      ...                 ...
# C1_OC_cell_TGCTACCGTCCGAACC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGGGCGTTCACTATTC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTCCCAGTAACGACG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTTCCGCAGGTCTCG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TTCTCAATCACCTTAT           C1_PT  Primary      Advanced stage
#
#                                      patient_id treatment recurrence  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGATGCGAC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG              P1     Naive  Sensitive
# ...                                         ...       ...        ...
# C1_OC_cell_TGCTACCGTCCGAACC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGGGCGTTCACTATTC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTCCCAGTAACGACG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTTCCGCAGGTCTCG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TTCTCAATCACCTTAT      Carcinosarcoma     Naive  Sensitive
#
#                                 tumor_stage              paper_ID  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGATGCGAC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG        IIIC               Zheng_1
# ...                                     ...                   ...
# C1_OC_cell_TGCTACCGTCCGAACC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGGGCGTTCACTATTC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTCCCAGTAACGACG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTTCCGCAGGTCTCG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TTCTCAATCACCTTAT            IIIC  Zheng_Carcinosarcoma
#
#                                 anatomical_location dataset
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGATGCGAC               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG               Blood   Zheng
# ...                                             ...     ...
# C1_OC_cell_TGCTACCGTCCGAACC                   Ovary   Zheng
# C1_OC_cell_TGGGCGTTCACTATTC                   Ovary   Zheng
# C1_OC_cell_TGTCCCAGTAACGACG                   Ovary   Zheng
# C1_OC_cell_TGTTCCGCAGGTCTCG                   Ovary   Zheng
# C1_OC_cell_TTCTCAATCACCTTAT                   Ovary   Zheng
#
# [223363 rows x 10 columns]

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs.n_genes_by_counts < 7000, :]
adata = adata[adata.obs.pct_counts_mt < 8, :]

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
adata.write("/group/testa/Project/OvarianAtlas/Zheng2023/Adata/zheng2023_wholedataset_filt_norm_nolog.h5ad")

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.tl.pca(adata, svd_solver='arpack', use_highly_variable=True)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['tissue'], frameon = False)
sc.pl.umap(adata, color=['treatment'], frameon = False)
sc.pl.umap(adata, color=['paper_ID'], frameon = False)
sc.pl.umap(adata, color=['anatomical_location'], frameon = False)

# %%
adata.write("/group/testa/Project/OvarianAtlas/Zheng2023/Adata/zheng2023_wholedataset_embeddings.h5ad")

# %% [markdown]
# ## Considering only HGSOC data and removing blood and lymph nodes

# %%
adata = sc.read('/group/testa/Project/OvarianAtlas/Zheng2023/Adata/zheng2023_rawcounts.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 223363 × 27117
#     obs: 'sample_name', 'tissue', 'developmental_stage', 'patient_id', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata.obs
# Out:
#                                 sample_name   tissue developmental_stage  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGATGCGAC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG   HGSOC1_BC    Blood      Advanced stage
# ...                                     ...      ...                 ...
# C1_OC_cell_TGCTACCGTCCGAACC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGGGCGTTCACTATTC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTCCCAGTAACGACG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTTCCGCAGGTCTCG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TTCTCAATCACCTTAT           C1_PT  Primary      Advanced stage
#
#                                      patient_id treatment recurrence  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGATGCGAC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG              P1     Naive  Sensitive
# ...                                         ...       ...        ...
# C1_OC_cell_TGCTACCGTCCGAACC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGGGCGTTCACTATTC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTCCCAGTAACGACG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTTCCGCAGGTCTCG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TTCTCAATCACCTTAT      Carcinosarcoma     Naive  Sensitive
#
#                                 tumor_stage              paper_ID  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGATGCGAC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG        IIIC               Zheng_1
# ...                                     ...                   ...
# C1_OC_cell_TGCTACCGTCCGAACC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGGGCGTTCACTATTC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTCCCAGTAACGACG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTTCCGCAGGTCTCG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TTCTCAATCACCTTAT            IIIC  Zheng_Carcinosarcoma
#
#                                 anatomical_location dataset  n_genes  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT               Blood   Zheng     1660
# EOC1_PBMC_cell_AAACCTGAGATGCGAC               Blood   Zheng     4372
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA               Blood   Zheng     1635
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC               Blood   Zheng     1625
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG               Blood   Zheng     1269
# ...                                             ...     ...      ...
# C1_OC_cell_TGCTACCGTCCGAACC                   Ovary   Zheng     4985
# C1_OC_cell_TGGGCGTTCACTATTC                   Ovary   Zheng     5798
# C1_OC_cell_TGTCCCAGTAACGACG                   Ovary   Zheng     1583
# C1_OC_cell_TGTTCCGCAGGTCTCG                   Ovary   Zheng     2141
# C1_OC_cell_TTCTCAATCACCTTAT                   Ovary   Zheng     3496
#
#                                  n_genes_by_counts  total_counts  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT               1660        6736.0
# EOC1_PBMC_cell_AAACCTGAGATGCGAC               4372       33886.0
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA               1635        4998.0
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC               1625        6397.0
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG               1269        3766.0
# ...                                            ...           ...
# C1_OC_cell_TGCTACCGTCCGAACC                   4985       20793.0
# C1_OC_cell_TGGGCGTTCACTATTC                   5798       24396.0
# C1_OC_cell_TGTCCCAGTAACGACG                   1583        3354.0
# C1_OC_cell_TGTTCCGCAGGTCTCG                   2141        6056.0
# C1_OC_cell_TTCTCAATCACCTTAT                   3496       10310.0
#
#                                  total_counts_mt  pct_counts_mt
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT            199.0       2.954276
# EOC1_PBMC_cell_AAACCTGAGATGCGAC           1661.0       4.901729
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA            179.0       3.581433
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC            157.0       2.454275
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG            227.0       6.027616
# ...                                          ...            ...
# C1_OC_cell_TGCTACCGTCCGAACC               1401.0       6.737844
# C1_OC_cell_TGGGCGTTCACTATTC                961.0       3.939170
# C1_OC_cell_TGTCCCAGTAACGACG                133.0       3.965414
# C1_OC_cell_TGTTCCGCAGGTCTCG                540.0       8.916777
# C1_OC_cell_TTCTCAATCACCTTAT                446.0       4.325897
#
# [223363 rows x 15 columns]

# %%
adata.obs.drop(columns=['n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'], inplace=True)

# %%
adata.obs
# Out:
#                                 sample_name   tissue developmental_stage  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGATGCGAC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC   HGSOC1_BC    Blood      Advanced stage
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG   HGSOC1_BC    Blood      Advanced stage
# ...                                     ...      ...                 ...
# C1_OC_cell_TGCTACCGTCCGAACC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGGGCGTTCACTATTC           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTCCCAGTAACGACG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTTCCGCAGGTCTCG           C1_PT  Primary      Advanced stage
# C1_OC_cell_TTCTCAATCACCTTAT           C1_PT  Primary      Advanced stage
#
#                                      patient_id treatment recurrence  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGATGCGAC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC              P1     Naive  Sensitive
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG              P1     Naive  Sensitive
# ...                                         ...       ...        ...
# C1_OC_cell_TGCTACCGTCCGAACC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGGGCGTTCACTATTC      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTCCCAGTAACGACG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTTCCGCAGGTCTCG      Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TTCTCAATCACCTTAT      Carcinosarcoma     Naive  Sensitive
#
#                                 tumor_stage              paper_ID  \
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGATGCGAC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC        IIIC               Zheng_1
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG        IIIC               Zheng_1
# ...                                     ...                   ...
# C1_OC_cell_TGCTACCGTCCGAACC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGGGCGTTCACTATTC            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTCCCAGTAACGACG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTTCCGCAGGTCTCG            IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TTCTCAATCACCTTAT            IIIC  Zheng_Carcinosarcoma
#
#                                 anatomical_location dataset
# EOC1_PBMC_cell_AAACCTGAGAAGGCCT               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGATGCGAC               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGCTGTTCA               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGGGTCTCC               Blood   Zheng
# EOC1_PBMC_cell_AAACCTGAGGTGCTAG               Blood   Zheng
# ...                                             ...     ...
# C1_OC_cell_TGCTACCGTCCGAACC                   Ovary   Zheng
# C1_OC_cell_TGGGCGTTCACTATTC                   Ovary   Zheng
# C1_OC_cell_TGTCCCAGTAACGACG                   Ovary   Zheng
# C1_OC_cell_TGTTCCGCAGGTCTCG                   Ovary   Zheng
# C1_OC_cell_TTCTCAATCACCTTAT                   Ovary   Zheng
#
# [223363 rows x 10 columns]

# %%
adata.obs.tissue.unique()
# Out:
# ['Blood', 'Primary', 'Metastasis', 'Ascites', 'Lymph node']
# Categories (5, object): ['Ascites', 'Blood', 'Lymph node', 'Metastasis', 'Primary']

# %%
mask = ((adata.obs['tissue'] != 'Blood') & (adata.obs['tissue'] != 'Lymph node'))

# %%
mask.sum()
# Out:
# 146888

# %%
(adata.obs['tissue'] == 'Blood').sum()
# Out:
# 35501

# %%
(adata.obs['tissue'] == 'Lymph node').sum()
# Out:
# 40974

# %%
((adata.obs['tissue'] == 'Blood') | (adata.obs['tissue'] == 'Lymph node')).sum()
# Out:
# 76475

# %%
adata = adata[mask]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 146888 × 27117
#     obs: 'sample_name', 'tissue', 'developmental_stage', 'patient_id', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata.obs
# Out:
#                               sample_name   tissue developmental_stage  \
# EOC1_OC_cell_AAACCTGAGATGCGAC   HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAACCTGCAGCTGCAC   HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAACCTGGTGATAAAC   HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAAGATGAGCTAAACA   HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAAGTAGAGCGTCTAT   HGSOC1_PT  Primary      Advanced stage
# ...                                   ...      ...                 ...
# C1_OC_cell_TGCTACCGTCCGAACC         C1_PT  Primary      Advanced stage
# C1_OC_cell_TGGGCGTTCACTATTC         C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTCCCAGTAACGACG         C1_PT  Primary      Advanced stage
# C1_OC_cell_TGTTCCGCAGGTCTCG         C1_PT  Primary      Advanced stage
# C1_OC_cell_TTCTCAATCACCTTAT         C1_PT  Primary      Advanced stage
#
#                                    patient_id treatment recurrence  \
# EOC1_OC_cell_AAACCTGAGATGCGAC              P1     Naive  Sensitive
# EOC1_OC_cell_AAACCTGCAGCTGCAC              P1     Naive  Sensitive
# EOC1_OC_cell_AAACCTGGTGATAAAC              P1     Naive  Sensitive
# EOC1_OC_cell_AAAGATGAGCTAAACA              P1     Naive  Sensitive
# EOC1_OC_cell_AAAGTAGAGCGTCTAT              P1     Naive  Sensitive
# ...                                       ...       ...        ...
# C1_OC_cell_TGCTACCGTCCGAACC    Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGGGCGTTCACTATTC    Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTCCCAGTAACGACG    Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TGTTCCGCAGGTCTCG    Carcinosarcoma     Naive  Sensitive
# C1_OC_cell_TTCTCAATCACCTTAT    Carcinosarcoma     Naive  Sensitive
#
#                               tumor_stage              paper_ID  \
# EOC1_OC_cell_AAACCTGAGATGCGAC        IIIC               Zheng_1
# EOC1_OC_cell_AAACCTGCAGCTGCAC        IIIC               Zheng_1
# EOC1_OC_cell_AAACCTGGTGATAAAC        IIIC               Zheng_1
# EOC1_OC_cell_AAAGATGAGCTAAACA        IIIC               Zheng_1
# EOC1_OC_cell_AAAGTAGAGCGTCTAT        IIIC               Zheng_1
# ...                                   ...                   ...
# C1_OC_cell_TGCTACCGTCCGAACC          IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGGGCGTTCACTATTC          IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTCCCAGTAACGACG          IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TGTTCCGCAGGTCTCG          IIIC  Zheng_Carcinosarcoma
# C1_OC_cell_TTCTCAATCACCTTAT          IIIC  Zheng_Carcinosarcoma
#
#                               anatomical_location dataset
# EOC1_OC_cell_AAACCTGAGATGCGAC               Ovary   Zheng
# EOC1_OC_cell_AAACCTGCAGCTGCAC               Ovary   Zheng
# EOC1_OC_cell_AAACCTGGTGATAAAC               Ovary   Zheng
# EOC1_OC_cell_AAAGATGAGCTAAACA               Ovary   Zheng
# EOC1_OC_cell_AAAGTAGAGCGTCTAT               Ovary   Zheng
# ...                                           ...     ...
# C1_OC_cell_TGCTACCGTCCGAACC                 Ovary   Zheng
# C1_OC_cell_TGGGCGTTCACTATTC                 Ovary   Zheng
# C1_OC_cell_TGTCCCAGTAACGACG                 Ovary   Zheng
# C1_OC_cell_TGTTCCGCAGGTCTCG                 Ovary   Zheng
# C1_OC_cell_TTCTCAATCACCTTAT                 Ovary   Zheng
#
# [146888 rows x 10 columns]

# %%
adata.obs.paper_ID.unique()
# Out:
# ['Zheng_1', 'Zheng_3', 'Zheng_2', 'Zheng_7', 'Zheng_Undifferentiated', ..., 'Zheng_8', 'Zheng_9', 'Zheng_Endometroid_carcinoma', 'Zheng_10', 'Zheng_Carcinosarcoma']
# Length: 14
# Categories (14, object): ['Zheng_1', 'Zheng_2', 'Zheng_3', 'Zheng_4', ..., 'Zheng_Carcinosarcoma', 'Zheng_Clear cell carcinoma', 'Zheng_Endometroid_carcinoma', 'Zheng_Undifferentiated']

# %%
mask2 = ((adata.obs['paper_ID'] != 'Zheng_Carcinosarcoma') & 
        (adata.obs['paper_ID'] != 'Zheng_Clear cell carcinoma') & 
        (adata.obs['paper_ID'] != 'Zheng_Endometroid_carcinoma') & 
        (adata.obs['paper_ID'] != 'Zheng_Undifferentiated'))

# %%
mask2.sum()
# Out:
# 104913

# %%
adata = adata[mask2]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 104913 × 27117
#     obs: 'sample_name', 'tissue', 'developmental_stage', 'patient_id', 'treatment', 'recurrence', 'tumor_stage', 'paper_ID', 'anatomical_location', 'dataset'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata.obs
# Out:
#                                sample_name   tissue developmental_stage  \
# EOC1_OC_cell_AAACCTGAGATGCGAC    HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAACCTGCAGCTGCAC    HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAACCTGGTGATAAAC    HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAAGATGAGCTAAACA    HGSOC1_PT  Primary      Advanced stage
# EOC1_OC_cell_AAAGTAGAGCGTCTAT    HGSOC1_PT  Primary      Advanced stage
# ...                                    ...      ...                 ...
# EOC10_OC_cell_TCTTTCCGTCCAACTA  HGSOC10_PT  Primary      Advanced stage
# EOC10_OC_cell_TGATTTCAGGTGCAAC  HGSOC10_PT  Primary      Advanced stage
# EOC10_OC_cell_TGCGTGGCACTAAGTC  HGSOC10_PT  Primary      Advanced stage
# EOC10_OC_cell_TGCGTGGCATACCATG  HGSOC10_PT  Primary      Advanced stage
# EOC10_OC_cell_TTATGCTCAATAACGA  HGSOC10_PT  Primary      Advanced stage
#
#                                patient_id treatment recurrence tumor_stage  \
# EOC1_OC_cell_AAACCTGAGATGCGAC          P1     Naive  Sensitive        IIIC
# EOC1_OC_cell_AAACCTGCAGCTGCAC          P1     Naive  Sensitive        IIIC
# EOC1_OC_cell_AAACCTGGTGATAAAC          P1     Naive  Sensitive        IIIC
# EOC1_OC_cell_AAAGATGAGCTAAACA          P1     Naive  Sensitive        IIIC
# EOC1_OC_cell_AAAGTAGAGCGTCTAT          P1     Naive  Sensitive        IIIC
# ...                                   ...       ...        ...         ...
# EOC10_OC_cell_TCTTTCCGTCCAACTA        P10     Naive  Sensitive        IIIC
# EOC10_OC_cell_TGATTTCAGGTGCAAC        P10     Naive  Sensitive        IIIC
# EOC10_OC_cell_TGCGTGGCACTAAGTC        P10     Naive  Sensitive        IIIC
# EOC10_OC_cell_TGCGTGGCATACCATG        P10     Naive  Sensitive        IIIC
# EOC10_OC_cell_TTATGCTCAATAACGA        P10     Naive  Sensitive        IIIC
#
#                                 paper_ID anatomical_location dataset
# EOC1_OC_cell_AAACCTGAGATGCGAC    Zheng_1               Ovary   Zheng
# EOC1_OC_cell_AAACCTGCAGCTGCAC    Zheng_1               Ovary   Zheng
# EOC1_OC_cell_AAACCTGGTGATAAAC    Zheng_1               Ovary   Zheng
# EOC1_OC_cell_AAAGATGAGCTAAACA    Zheng_1               Ovary   Zheng
# EOC1_OC_cell_AAAGTAGAGCGTCTAT    Zheng_1               Ovary   Zheng
# ...                                  ...                 ...     ...
# EOC10_OC_cell_TCTTTCCGTCCAACTA  Zheng_10               Ovary   Zheng
# EOC10_OC_cell_TGATTTCAGGTGCAAC  Zheng_10               Ovary   Zheng
# EOC10_OC_cell_TGCGTGGCACTAAGTC  Zheng_10               Ovary   Zheng
# EOC10_OC_cell_TGCGTGGCATACCATG  Zheng_10               Ovary   Zheng
# EOC10_OC_cell_TTATGCTCAATAACGA  Zheng_10               Ovary   Zheng
#
# [104913 rows x 10 columns]

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs.n_genes_by_counts < 7000, :]
adata = adata[adata.obs.pct_counts_mt < 8, :]

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
adata.write("/group/testa/Project/OvarianAtlas/Zheng2023/Adata/zheng2023_filt_norm_nolog.h5ad")

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pl.highly_variable_genes(adata)

# %%
sc.tl.pca(adata, svd_solver='arpack', use_highly_variable=True)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['tissue'], frameon = False)
sc.pl.umap(adata, color=['treatment'], frameon = False)
sc.pl.umap(adata, color=['patient_id'], frameon = False)
sc.pl.umap(adata, color=['anatomical_location'], frameon = False)

# %%
adata.write("/group/testa/Project/OvarianAtlas/Zheng2023/Adata/zheng2023_embeddings.h5ad")
